# %%
import json
import matplotlib as pyplot
import datetime as datetime
import requests
import pandas as pd
import numpy as np

response = requests.get("https://api.stlouisfed.org/fred/release/tables?element_id=259515&release_id=249&observation_date=2019-01-01&api_key=1a926786f5bb1f32dbbd46e0670197c2&file_type=json") 
data = response.json()
api_status = response.status_code
print(api_status)

main_data = data.get("elements")

new_name = []
new_code = []
id_list = list(range(259516, 259568))
str_list = []
for i in id_list:
    str_list.append(str(i))

num10 = list(range(0, 10))

for i in str_list:
    new_name.append(main_data[i]["name"])
    new_code.append(main_data[i]["series_id"])

new_dict = dict(zip(new_name, new_code)) 

#Here is the entire dictionary consisting states names and codes
#including the national level

"""
url_base = "https://api.stlouisfed.org/fred/series/observations?series_id={}&observation_start=2011-01-01&api_key=1a926786f5bb1f32dbbd46e0670197c2&file_type=json"


for i in new_name:
    url = url_base.format(new_dict[i])
    data = requests.get(url).json()
    fileName = "DSP_" + str(i) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(data, outfile, ensure_ascii=False, indent=4)

#Generated jsons, each with income from 2011 to 2020 of invidivual state
#Folder: Income by States



for i in num10:
    num_yearly_list = []
    for n in new_name:
        url = url_base.format(new_dict[n])
        data = requests.get(url).json()
        num_yearly_list.append(data["observations"][i]["value"])
    data = dict(zip(new_name, num_yearly_list))
    fileName = "DSP_income_" + str(i+2011) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(data, outfile, ensure_ascii=False, indent=4)

#Generated jsons, each with income from all states in a specific year
#Folder: All Income by Year

url_base = "https://api.usa.gov/crime/fbi/sapi/api/police-employment/regions/{}/2011/2020?api_key=BbizKwLOEBflbnbBw91NhHJWoWItbq1vp4y2LY06"

region_code = ["west", "midwest", "south", "northeast"]
for i in region_code:
    url = url_base.format(i)
    data = requests.get(url).json()
    fileName = "DSP_Police_All_Year_" + str(i) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(data, outfile, ensure_ascii=False, indent=4)

#Generated jsons, each with total regional police number from 2011 to 2020
#Folder: Police All Year by Region

url_base0 = "https://worldpopulationreview.com/static/states/name-abbr.json"
url_base = "https://api.usa.gov/crime/fbi/sapi/api/police-employment/states/{}/2011/2020?api_key=BbizKwLOEBflbnbBw91NhHJWoWItbq1vp4y2LY06"


new_name[9] = "District Of Columbia"
name_list = []
for i in new_name[1:]:
    data = requests.get(url_base0).json()
    name_list.append(data[i])

#Generated short abbreviation of names of states for indexing

for i in name_list:
    url = url_base.format(i)
    data = requests.get(url).json()
    fileName = "DSP_Police_All_Year_" + str(i) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(data, outfile, ensure_ascii=False, indent=4)

#Generated jsons each with total police number of each states across years
#Folder: Police All Year by States

new_name[9] = "District of Columbia"
new_name = new_name[1:]
for i in num10:
    num_yearly_list = []
    for n in name_list:
        url = url_base.format(n)
        data = requests.get(url).json()
        num_yearly_list.append(data["results"][i]["total_pe_ct"])
    data = dict(zip(new_name, num_yearly_list))
    fileName = "DSP_Police_All_" + str(i+2011) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(data, outfile, ensure_ascii=False, indent=4)

#Generated jsons each with total police number of each state separately of a specific year
#Folder: All Police by Year

new_name[9] = "District of Columbia"
new_name = new_name[1:]
print(name_list)

num_yearly_list = []
for n in name_list:
    url = url_base.format(n)
    data = requests.get(url).json()
    num_yearly_list.append(data["results"][9]["total_pe_ct"])
    data = dict(zip(new_name, num_yearly_list))
    fileName = "DSP_Police_All_" + str(2020) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(data, outfile, ensure_ascii=False, indent=4)

#same as above but with a missing entry of state WV in 2014


url = "https://raw.githubusercontent.com/cphalpert/census-regions/master/us%20census%20bureau%20regions%20and%20divisions.csv"
c = pd.read_csv(url)
name_list = []
region_list = []

for i in range(0, len(c['State'])):
    name_list.append(c['State'][i])
    region_list.append(c['Region'][i])
name_region_pair = dict(zip(name_list, region_list))
fileName = "DSP_states_to_region.json" 
with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(name_region_pair, outfile, ensure_ascii=False, indent=4)



url_base_income = "https://raw.githubusercontent.com/ln18323/ln18323.github.io/main/DS%20Project%20Data%20Folder/2011-2020%20All%20Income%20by%20Year/DSP_income_{}.json"
url_base_police = "https://raw.githubusercontent.com/ln18323/ln18323.github.io/main/DS%20Project%20Data%20Folder/2011-2020%20All%20Police%20by%20Year/DSP_Police_All_{}.json"
url_base_national_police = "https://api.usa.gov/crime/fbi/sapi/api/police-employment/national/2011/2020?api_key=BbizKwLOEBflbnbBw91NhHJWoWItbq1vp4y2LY06"
url_base_region = "https://raw.githubusercontent.com/ln18323/ln18323.github.io/main/DS%20Project%20Data%20Folder/DSP_states_to_region.json"
year_list = list(range(0, 10))

for n in year_list:
    dict_single_pair = {}
    dict_entire_list = []
    url = url_base_income.format(n+2011)
    data = requests.get(url).json()
    url_1 = url_base_police.format(n+2011)
    data_1 = requests.get(url_1).json()
    data_2 = requests.get(url_base_national_police).json()
    data_3 = requests.get(url_base_region).json()
    for i in data.keys():
        if i == "The United States":
            dict_single_pair.update({"name": i, "income": data[i], "police_total": np.ceil(data_2["results"][n]["total_pe_ct"]/51), "region": "USA"})
            one_pair = dict_single_pair.copy()
            dict_entire_list.append(one_pair)
        else:
            dict_single_pair.update({"name": i, "income": data[i], "police_total": data_1[i], "region": data_3[i]})
            one_pair = dict_single_pair.copy()
            dict_entire_list.append(one_pair)
    fileName = "DSP_combined_" + str(n+2011) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(dict_entire_list, outfile, ensure_ascii=False, indent=4)

#Combined every factors in a dictionary, while Washington DC is counted too as a state

url_combined_base = "https://raw.githubusercontent.com/ln18323/ln18323.github.io/main/DS%20Project%20Data%20Folder/2011-2020%20Combined%20by%20Year/DSP_combined_{}.json"
year_list = range(0, 10)
url_combined = url_combined_base.format(2011)
data = requests.get(url_combined).json()
name_list = []
for i in range(0, len(data)):
    name_list.append(data[i]['name'])

for n in name_list:
    name_index = name_list.index(n)
    new_data = []
    for j in year_list:
        url_combined = url_combined_base.format(j+2011)
        data = requests.get(url_combined).json()
        single_observation = data[name_index].copy()
        new_year = {"year": j+2011}
        single_observation.update(new_year)
        added_single_observation = single_observation.copy()
        new_data.append(added_single_observation)
    fileName = "DSP_detailed_" + str(n) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(new_data, outfile, ensure_ascii=False, indent=4)

#added the year for interactive chart 1 according to States and Year.
#Folder: 2011-2020 Detailed by States and Year

ab_list = ["fl", "ny", "tx", "ca"]
name_list = ["Florida", "New York", "Texas", "California"]
abname_dict = dict(zip(ab_list, name_list))
key_words = ["Aggravated Assault", "Burglary", "Larceny", "Motor Vehicle Theft", "Rape", "Robbery", "Arson"]
url_base = "https://api.usa.gov/crime/fbi/sapi/api/arrest/states/offense/{}/all/2011/2020?api_key=BbizKwLOEBflbnbBw91NhHJWoWItbq1vp4y2LY06"
year_list = range(2011, 2021)
for n in ab_list:
    url = url_base.format(n)
    data = requests.get(url).json()
    c = 0
    each_pair = {}
    total_pair = []
    for i in year_list:
        c = 0
        for m in key_words:
            for j in range(0, len(data["data"])):
                if data["data"][j]["key"] == m and data["data"][j]["data_year"] == i:
                    c += data["data"][j]["value"]
        new_pair = {"year": i, "value": c, "name": abname_dict[n] } 
        p = new_pair.copy()
        total_pair.append(p)
    fileName = "DSP_4arrest_" + str(abname_dict[n]) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(total_pair, outfile, ensure_ascii=False, indent=4)    

#generated json each for the arrested trend across the years
#Folder: 2011-2020 4arrest All Year


ab_list = ["fl", "ny", "tx", "ca"]
name_list = ["Florida", "New York", "Texas", "California"]
abname_dict = dict(zip(ab_list, name_list))
offense_list = ["aggravated-assault", "burglary", "larceny", "motor-vehicle-theft", "rape", "robbery", "arson"]
url_base1 = "https://api.usa.gov/crime/fbi/sapi/api/summarized/state/{}"
url_base2 = "/{}/"
url_base3 = "{}/2020?api_key=BbizKwLOEBflbnbBw91NhHJWoWItbq1vp4y2LY06"
year_list = range(2011, 2021)
for n in ab_list:
    url1 = url_base1.format(n)
    c = 0
    each_pair = {}
    total_pair = []
    for i in year_list:
      c = 0
      url3 = url_base3.format(i)
      for m in offense_list:
          url2 = url_base2.format(m)
          url = url1 + url2 + url3
          data = requests.get(url).json()
          for j in range(0, len(data["results"])):
              if data["results"][j]["data_year"] == i:
                  c += data["results"][j]["actual"]
      new_pair = {"year": i, "value": c, "name": abname_dict[n] } 
      p = new_pair.copy()
      total_pair.append(p)
    fileName = "DSP_4offense_" + str(abname_dict[n]) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(total_pair, outfile, ensure_ascii=False, indent=4)    


name_list = ["New York", "Texas", "California"]
year_list = range(2011, 2021)
url_base1 = "https://raw.githubusercontent.com/ln18323/ln18323.github.io/main/DS%20Project%20Data%20Folder/2011-2020%204offense%20All%20Year/DSP_4offense_{}.json"
url_base2 = "https://raw.githubusercontent.com/ln18323/ln18323.github.io/main/DS%20Project%20Data%20Folder/2011-2020%204arrest%20All%20Year/DSP_4arrest_{}.json"
url_base3 = "https://raw.githubusercontent.com/ln18323/ln18323.github.io/main/DS%20Project%20Data%20Folder/2011-2020%20Income%20by%20States/DSP_{}.json"
name = []
year = []
arrest = []
offense = []
a_o_ratio = []
income = []
for n in name_list:
    url1 = url_base1.format(n)
    data1 = requests.get(url1).json()
    url2 = url_base2.format(n)
    data2 = requests.get(url2).json()
    url3 = url_base3.format(n)
    data3 = requests.get(url3).json()
    for i in year_list:
        for m in data1:
            if m["year"] == i and m["name"] == n:
                m_index = data1.index(m)
                name.append(n)
                year.append(i)
                offense.append(data1[m_index]["value"])
                arrest.append(data2[m_index]["value"])
                a_o_ratio.append(data2[m_index]["value"]/ data1[m_index]["value"])
                income.append(data3["observations"][m_index]["value"])
data_dict = {"year": [i for i in year], "name": [j for j in name], "offense": [k for k in offense], "arrest": [l for l in arrest], "a_o_ratio": [y for y in a_o_ratio], "income": [a for a in income]}
data = pd.DataFrame(data_dict)
data.head()
data.to_csv("2011-2020 offense arrest 3cities.csv", index = False)
#generated csv

name_url = "https://worldpopulationreview.com/static/states/name-abbr.json"
key_words = ["Aggravated Assault", "Burglary", "Larceny", "Motor Vehicle Theft", "Rape", "Robbery", "Arson"]
url_base = "https://api.usa.gov/crime/fbi/sapi/api/arrest/states/offense/{}/all/2011/2020?api_key=BbizKwLOEBflbnbBw91NhHJWoWItbq1vp4y2LY06"
year_list = range(2011, 2021)
n_data = requests.get(name_url).json()
name_long =[]
name_short = []
for t in n_data.keys():
    name_long.append(t)
for t1 in n_data.values():
    name_short.append(t1)
name_long[8] = "District of Columbia"
for n in name_short:
    url = url_base.format(n)
    data = requests.get(url).json()
    c = 0
    each_pair = {}
    total_pair = []
    for i in year_list:
        c = 0
        for m in key_words:
            for j in range(0, len(data["data"])):
                if data["data"][j]["key"] == m and data["data"][j]["data_year"] == i:
                    c += data["data"][j]["value"]
        new_pair = {"year": i, "value": c, "name": name_long[name_short.index(n)] } 
        p = new_pair.copy()
        total_pair.append(p)
    fileName = "DSP_MEGA_arrest_" + str(name_long[name_short.index(n)]) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(total_pair, outfile, ensure_ascii=False, indent=4)    

#generated mega arrest all year

name_url = "https://worldpopulationreview.com/static/states/name-abbr.json"
offense_list = ["aggravated-assault", "burglary", "larceny", "motor-vehicle-theft", "rape", "robbery", "arson"]
url_base1 = "https://api.usa.gov/crime/fbi/sapi/api/summarized/state/{}"
url_base2 = "/{}/"
url_base3 = "{}/2020?api_key=BbizKwLOEBflbnbBw91NhHJWoWItbq1vp4y2LY06"
year_list = range(2011, 2021)
n_data = requests.get(name_url).json()
name_long =[]
name_short = []
for t in n_data.keys():
    name_long.append(t)
for t1 in n_data.values():
    name_short.append(t1)
name_long[8] = "District of Columbia"
for n in name_short[21:]:
    url1 = url_base1.format(n)
    c = 0
    each_pair = {}
    total_pair = []
    for i in year_list:
      c = 0
      url3 = url_base3.format(i)
      for m in offense_list:
          url2 = url_base2.format(m)
          url = url1 + url2 + url3
          data = requests.get(url).json()
          for j in range(0, len(data["results"])):
              if data["results"][j]["data_year"] == i:
                  c += data["results"][j]["actual"]
          print(i, m)
      new_pair = {"year": i, "value": c, "name": name_long[name_short.index(n)] } 
      p = new_pair.copy()
      total_pair.append(p)
    fileName = "DSP_MEGA_offense_" + str(name_long[name_short.index(n)]) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(total_pair, outfile, ensure_ascii=False, indent=4)    
#produce MEGA offense
# Out:
# 200
# 2011 aggravated-assault
# 2011 burglary
# 2011 larceny
# 2011 motor-vehicle-theft
# 2011 rape
# 2011 robbery
# 2011 arson
# 2012 aggravated-assault
# 2012 burglary
# 2012 larceny
# 2012 motor-vehicle-theft
# 2012 rape
# 2012 robbery
# 2012 arson
# 2013 aggravated-assault
# 2013 burglary
# 2013 larceny
# 2013 motor-vehicle-theft
# 2013 rape
# 2013 robbery
# 2013 arson
# 2014 aggravated-assault
# 2014 burglary
# 2014 larceny
# 2014 motor-vehicle-theft
# 2014 rape
# 2014 robbery
# 2014 arson
# 2015 aggravated-assault
# 2015 burglary
# 2015 larceny
# 2015 motor-vehicle-theft
# 2015 rape
# 2015 robbery
# 2015 arson
# 2016 aggravated-assault
# 2016 burglary
# 2016 larceny
# 2016 motor-vehicle-theft
# 2016 rape
# 2016 robbery
# 2016 arson
# 2017 aggravated-assault
# 2017 burglary
# 2017 larceny
# 2017 motor-vehicle-theft
# 2017 rape
# 2017 robbery
# 2017 arson
# 2018 aggravated-assault
# 2018 burglary
# 2018 larceny
# 2018 motor-vehicle-theft
# 2018 rape
# 2018 robbery
# 2018 arson
# ...

# %%
url_base = "https://raw.githubusercontent.com/ln18323/ln18323.github.io/main/DS%20Project%20Data%20Folder/2011-2020%20All%20Income%20by%20Year/DSP_income_{}.json"
year_list = range(2011, 2021)
psum = []
per = []
for n in new_name:
    psum = []
    per = []
    for i in year_list:
        if i < 2020:
            url = url_base.format(i)
            url1 = url_base.format(i+1)
            data = requests.get(url)
            data1 = requests.get(url1)
            i_num = new_name.index(n)
            per = (data1[i_num] - data[i_num])/data[i_num]
            psum.append(per)
    income_pair = {"name": n, "income_total_p": psum}
    fileName = "DSP_income_psum_" + str(n) +".json" 
    with open(fileName, 'w', encoding='utf-8') as outfile:
        json.dump(income_pair, outfile, ensure_ascii=False, indent=4)

# %%
new_name
# Out:
# ['The United States',
#  'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']
